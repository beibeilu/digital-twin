# %%
import geopandas
import pandas as pd
import matplotlib as plt

# %% [markdown]
# Looking at geodata

# %%
tract = geopandas.read_file('Clean Data/geo_nyc_tract.geojson')
tract.head(1)
# Out:
#         GEO_ID   nta       nta_name  \
# 0  36005000100  BX98  Rikers Island
#
#                                             geometry
# 0  POLYGON ((1019965.737 226696.334, 1019943.935 ...

# %%
tract.nta.value_counts()
tract['boro'] = tract['nta'].apply(lambda s:str(s)[:2])

# %%
tract.head(1)
tract.plot(column='boro')
# Out:
# <AxesSubplot:>

# %%
tract.plot(column='nta')
# Out:
# <AxesSubplot:>

# %%
zipcode = geopandas.read_file('Clean Data/geo_nyc_zipcode.geojson')
zipcode.head(1)
# Out:
#   ZIPCODE  PO_NAME  POPULATION          AREA STATE  COUNTY ST_FIPS CTY_FIPS  \
# 0   11436  Jamaica     18681.0  2.269930e+07    NY  Queens      36      081
#
#                                             geometry
# 0  POLYGON ((1038098.252 188138.380, 1038141.936 ...

# %%
zipcode.plot(column='PO_NAME')
# Out:
# <AxesSubplot:>
